# %%
import csv
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt


companies = []
with open('companies.csv', newline='') as inputfile:
    for row in csv.reader(inputfile):
        companies.append(row[0])

print(companies[0:11])
# Out:
# ['Company', '4Insite', '7-Eleven, Inc.', 'A Place for Mom', 'A Place for Mom', 'Abiomed', 'Accenture', 'Activision', 'Agilent Technologies, Inc.', 'AIG', 'Akamai']

# %%
word_could_dict=Counter(companies)
wordcloud = WordCloud(width = 1600, height = 800,max_words=50,background_color='white').generate_from_frequencies(word_could_dict)
plt.figure(figsize=(40,30))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
word_could_dict
# Out:
# Counter({'Company': 1,
#          '4Insite': 1,
#          '7-Eleven, Inc.': 1,
#          'A Place for Mom': 2,
#          'Abiomed': 1,
#          'Accenture': 1,
#          'Activision': 1,
#          'Agilent Technologies, Inc.': 1,
#          'AIG': 1,
#          'Akamai': 1,
#          'Akraya Inc.': 1,
#          'Alion Science and Technology': 1,
#          'Alliance Data': 1,
#          'AllianceBernstein': 2,
#          'Allianz Global Investors': 1,
#          'Allstate': 2,
#          'AllWays Health Partners': 1,
#          'AlphaSights': 2,
#          'Alteryx, Inc.': 1,
#          'Amazon Data Services, Inc.': 1,
#          'Amazon.com Services LLC': 4,
#          'American Fidelity Assurance': 1,
#          'American Greetings': 1,
#          'Amerilife Group, LLC': 1,
#          'Ameriprise Financial': 1,
#          'Amgen': 2,
#          'Amplify Education, Inc.': 2,
#          'Amrock': 1,
#          'Ancestry': 1,
#          'Apple': 12,
#          'Applied Materials Inc.': 1,
#          'Argonne National Laboratory': 1,
#          'ASSURANCE': 1,
#          'AstraZeneca': 8,
#          'Athenahealth': 1,
#          'Atrium Health': 1,
#          'Avalon Healthcare Solutions': 1,
#          'AvalonBay Communities': 1,
#          'Avantor': 1,
#          'Bank of America': 2,
#          'BankUnited': 1,
#          'Barclays': 2,
#          'Battelle': 3,
#          'Bigbear.ai': 1,
#          'Bio-Rad Laboratories, Inc.': 1,
#          'Bio-Reference Laboratories, Inc.': 1,
#          'BlackRock': 1,
#          'Blizzard Entertainment': 1,
#          'Bloomberg': 1,
#          'Bolt': 1,
#          'Booz Allen Hamilton': 5,
#          'Boston Scientific Corporation': 1,
#          'Boston University': 1,
#          'Branch': 1,
#          "Brigham & Women's Hospital(BWH)": 1,
#          'Broadcom': 1,
#          'Broadridge': 1,
#          'Buchanan & Edwards': 1,
#          'Bumble': 2,
#          'C&S Wholesale Grocers, Inc.': 1,
#          'Capgemini': 4,
#          'Capital One - US': 2,
#          'CarGurus': 4,
#          'CarMax': 1,
#          'Catalent Pharma Solutions': 1,
#          'Cedar Inc': 2,
#          'Change Healthcare': 1,
#          'Child Trends': 1,
#          "Children's Healthcare of Atlanta": 1,
#          "Children's Hospital of Philadelphia": 1,
#          'Choctaw Nation': 1,
#          'Citi': 1,
#          'Citizens': 1,
#          'Clemson University': 1,
#          'Cognizant Technology Solutions': 1,
#          'Colgate-Palmolive': 1,
#          'Comcast': 1,
#          'Confluent': 1,
#          'Cottonwood Financial': 1,
#          'Credit Suisse': 1,
#          'Criteo': 1,
#          'CVS Health': 2,
#          'Daimler': 1,
#          'Dascena': 1,
#          'Dell Technologies': 1,
#          'Deloitte': 2,
#          'Delta': 1,
#          'Detroit Trading Company': 1,
#          'Deutsche Bank': 1,
#          'DEVCOM Army Research Laboratory': 1,
#          'Discord': 1,
#          'Discovery': 1,
#          'DocuSign': 1,
#          'Epsilon': 2,
#          'Eventbrite': 1,
#          'Exact Sciences Corporation': 2,
#          'Expedia Group': 2,
#          'Extra Space Storage': 1,
#          'ExtraHop Networks, Inc.': 1,
#          'Facebook': 10,
#          'Fannie Mae': 1,
#          'Feedzai': 2,
#          'Fidelity Investments': 2,
#          'First American': 1,
#          'First Republic Bank': 1,
#          'Fiserv, Inc.': 1,
#          'Flagstar Bank': 1,
#          'Ford Motor Company': 1,
#          'FourthWall Media': 1,
#          'Freeport McMoRan': 1,
#          'Fresenius Medical Care': 2,
#          'Frontier Communications': 1,
#          'G&J Pepsi-Cola Bottlers': 1,
#          'GA Academy': 1,
#          'GE Appliances': 1,
#          'GE Healthcare': 1,
#          'GeneDx': 1,
#          'Getty Images': 1,
#          'GSK': 1,
#          'Highspot': 1,
#          'HIMSS': 2,
#          'Hinge': 1,
#          'Home Depot / THD': 1,
#          'HotSchedules': 2,
#          'HP': 2,
#          'IBM': 1,
#          'ICF': 1,
#          'Ingram Micro': 1,
#          'Intel': 2,
#          'Intelsat': 1,
#          'Intone Networks': 2,
#          'Invesco': 2,
#          'IQVIA': 1,
#          'iRhythm Technologies': 1,
#          'IRI': 1,
#          'J.Crew': 1,
#          'Jefferies & Company, Inc.': 1,
#          'John Deere': 1,
#          'John Hancock': 1,
#          'Johns Hopkins University': 1,
#          'JPMorgan Chase Bank, N.A.': 2,
#          'Kaplan': 1,
#          'KPMG': 1,
#          'Kroll': 1,
#          "Lands' End": 1,
#          'Lawrence Berkeley National Laboratory': 1,
#          'Lawrence Livermore National Laboratory': 1,
#          'Leo Burnett': 1,
#          'Lieberman Research Worldwide': 1,
#          'Logic20/20': 1,
#          "Lowe's": 3,
#          'LPL Financial': 1,
#          'Lyra Health': 1,
#          'Macy’s': 2,
#          'managementsolutions': 2,
#          'Massachusetts General Hospital(MGH)': 1,
#          'MasterCard': 1,
#          'McKinsey & Company': 1,
#          'Medidata Solutions': 2,
#          'Medium': 1,
#          'Mercy': 1,
#          'MGIC': 1,
#          'Michigan Medicine': 1,
#          'Micron Technology': 2,
#          'Microsoft': 5,
#          'Mighty': 1,
#          'Mitre Corporation': 4,
#          'Morgan Stanley': 2,
#          'Mount Sinai': 1,
#          'MoveOn.org': 1,
#          'National Security Agency': 1,
#          'Naval Nuclear Laboratory': 1,
#          'Navy Federal Credit Union': 1,
#          'Netflix': 2,
#          'Neuberger Berman': 1,
#          'New York Life Insurance Co': 1,
#          'Nexient': 2,
#          'Nike': 1,
#          'Northwestern Mutual': 1,
#          'Novo Nordisk': 1,
#          'Numerator': 1,
#          'Nutrien Ltd.': 3,
#          'NYU Langone Health': 1,
#          "O'Reilly Media": 1,
#          'Opendoor': 1,
#          'opentext': 2,
#          'Oracle': 1,
#          'Osmose Utilities Services': 1,
#          'Pacific Northwest National Laboratory': 1,
#          'Pall': 1,
#          'Patagonia, Inc': 1,
#          'PATH': 1,
#          'Paycom Payroll Llc': 1,
#          'PayPal': 1,
#          'Penguin Random House LLC': 1,
#          'Penn State University': 1,
#          'PepsiCo': 1,
#          'Petco': 1,
#          'Pfizer': 1,
#          'Piper Companies': 1,
#          'PRICE WATERHOUSE COOPERS': 1,
#          'Procter & Gamble': 1,
#          'Progressive Leasing': 1,
#          'Proofpoint': 1,
#          'Prosper': 1,
#          'Protective Life Corporation': 1,
#          'Prudential': 1,
#          'Qualis Corporation': 1,
#          'Quicken Loans': 1,
#          'RADcube': 1,
#          'Realogy Holdings Corp': 1,
#          'Recruiter.com': 1,
#          'Redfin': 1,
#          'Renewable Energy Systems': 1,
#          'Rivian Automotive': 1,
#          'Roblox': 2,
#          'Roche': 1,
#          'Root Insurance Company': 1,
#          'SAIC': 1,
#          'Saks Fifth Avenue': 1,
#          'Salesforce': 3,
#          'Samsung Electronics': 2,
#          'Sarepta Therapeutics': 1,
#          'Schnucks': 1,
#          'Secureworks': 1,
#          'Sedgwick': 1,
#          'Shopify': 2,
#          'Sinclair Broadcast Group': 1,
#          'Smith Micro Software': 1,
#          'Sonalysts, Inc.': 1,
#          'Sony Pictures Entertainment, Inc.': 1,
#          'SOSi': 1,
#          'Southern Company': 1,
#          'Spectrum': 1,
#          'Spectrum Communications & Consulting Inc.': 1,
#          'Splunk': 1,
#          'Spotify': 6,
#          'Spring Health': 1,
#          'Stanford University': 1,
#          'Starbucks': 1,
#          'State Farm': 1,
#          'Steward Health Care Network': 1,
#          'Swiss Re': 1,
#          'Symetra': 1,
#          'Sysco': 1,
#          'Takeda Pharmaceuticals': 1,
#          'Technica Corporation': 1,
#          'Tesla': 2,
#          'Texas Oncology': 1,
#          'The Boston Consulting Group': 1,
#          'The Rector & Visitors of the University of Virginia': 1,
#          'The Topps Company': 1,
#          'The University of Pittsburgh': 2,
#          'The Walt Disney Company (Corporate)': 2,
#          'Thermo Fisher Scientific': 1,
#          'Toyota': 1,
#          'Truist Financial': 1,
#          'TuSimple': 3,
#          'Twitter': 3,
#          'Two Sigma Investments, LLC.': 3,
#          'U.Group': 1,
#          'Uber': 1,
#          'UCLA Health': 1,
#          'Unilever': 1,
#          'UNITED PARCEL SERVICE': 2,
#          'Universal Orlando': 1,
#          'University Hospitals': 1,
#          'University of Washington': 2,
#          'US Department of Energy': 2,
#          'US Mobile': 1,
#          'US National Park Service': 1,
#          'USAA': 1,
#          'Vectra': 1,
#          'Verizon': 1,
#          'VF Corporation': 1,
#          'Visa': 1,
#          'Vizient, Inc.': 2,
#          'Wake Forest Baptist Medical Center': 1,
#          'WALGREENS': 1,
#          'Warner Bros. Entertainment Group': 1,
#          'Warner Music Group': 1,
#          'Wayfair': 1,
#          'Waymo': 4,
#          'Weber Shandwick': 1,
#          'Welltower': 1,
#          'Windstream Communications': 1,
#          'Xperi': 1,
#          'Zebit': 1,
#          'Zeta Global': 1,
#          'Zoom Video Communications, Inc.': 1})
